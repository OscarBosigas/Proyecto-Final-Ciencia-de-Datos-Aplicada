# %%
#Importaciones necesarias

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %%
#El dataframe lo cargamos en una sola fila
Cosechas_1= pd.read_csv('Evaluaciones_Agropecuarias_Municipales_EVA.csv')

# %%
#En esta seccion se realiza la limpieza de datos

#Algunos datos numéricos no contienen ningun valor por lo que los reeemplazamos por 0  
Cosechas_1=Cosechas_1.replace("",0)

# %%
Cosechas_1.head(50)
# Out:
#     CÓD. \nDEP.        DEPARTAMENTO  CÓD. MUN.      MUNICIPIO  \
# 0            15              BOYACA      15114       BUSBANZA
# 1            25        CUNDINAMARCA      25754         SOACHA
# 2            25        CUNDINAMARCA      25214           COTA
# 3            54  NORTE DE SANTANDER      54405     LOS PATIOS
# 4            54  NORTE DE SANTANDER      54518       PAMPLONA
# 5            68           SANTANDER      68377     LA BELLEZA
# 6            25        CUNDINAMARCA      25754         SOACHA
# 7            25        CUNDINAMARCA      25214           COTA
# 8            54  NORTE DE SANTANDER      54518       PAMPLONA
# 9            68           SANTANDER      68377     LA BELLEZA
# 10           15              BOYACA      15516          PAIPA
# 11           19               CAUCA      19392      LA SIERRA
# 12           25        CUNDINAMARCA      25754         SOACHA
# 13           25        CUNDINAMARCA      25126         CAJICA
# 14           54  NORTE DE SANTANDER      54405     LOS PATIOS
# 15           54  NORTE DE SANTANDER      54518       PAMPLONA
# 16           19               CAUCA      19392      LA SIERRA
# 17           25        CUNDINAMARCA      25754         SOACHA
# 18           25        CUNDINAMARCA      25126         CAJICA
# 19           54  NORTE DE SANTANDER      54405     LOS PATIOS
# 20           54  NORTE DE SANTANDER      54518       PAMPLONA
# 21           19               CAUCA      19392      LA SIERRA
# 22           25        CUNDINAMARCA      25754         SOACHA
# 23           25        CUNDINAMARCA      25269     FACATATIVA
# 24           54  NORTE DE SANTANDER      54405     LOS PATIOS
# 25           54  NORTE DE SANTANDER      54518       PAMPLONA
# 26           19               CAUCA      19110   BUENOS AIRES
# 27           25        CUNDINAMARCA      25214           COTA
# 28           25        CUNDINAMARCA      25322         GUASCA
# 29           25        CUNDINAMARCA      25491        NOCAIMA
# 30           54  NORTE DE SANTANDER      54405     LOS PATIOS
# 31           54  NORTE DE SANTANDER      54518       PAMPLONA
# 32           76     VALLE DEL CAUCA      76563        PRADERA
# 33           19               CAUCA      19110   BUENOS AIRES
# 34           25        CUNDINAMARCA      25214           COTA
# 35           25        CUNDINAMARCA      25322         GUASCA
# 36           25        CUNDINAMARCA      25491        NOCAIMA
# 37           54  NORTE DE SANTANDER      54405     LOS PATIOS
# 38           54  NORTE DE SANTANDER      54518       PAMPLONA
# 39           17              CALDAS      17541    PENSILVANIA
# 40           19               CAUCA      19513        PADILLA
# 41           25        CUNDINAMARCA      25214           COTA
# 42           25        CUNDINAMARCA      25322         GUASCA
# 43           54  NORTE DE SANTANDER      54405     LOS PATIOS
# 44           54  NORTE DE SANTANDER      54518       PAMPLONA
# 45           86            PUTUMAYO      86755  SAN FRANCISCO
# 46           68           SANTANDER      68895       ZAPATOCA
# 47           15              BOYACA      15491          NOBSA
# 48           17              CALDAS      17541    PENSILVANIA
# 49           25        CUNDINAMARCA      25214           COTA
#
#    GRUPO \nDE CULTIVO SUBGRUPO \nDE CULTIVO CULTIVO  \
# 0          HORTALIZAS                ACELGA  ACELGA
# 1          HORTALIZAS                ACELGA  ACELGA
# 2          HORTALIZAS                ACELGA  ACELGA
# 3          HORTALIZAS                ACELGA  ACELGA
# 4          HORTALIZAS                ACELGA  ACELGA
# 5          HORTALIZAS                ACELGA  ACELGA
# 6          HORTALIZAS                ACELGA  ACELGA
# 7          HORTALIZAS                ACELGA  ACELGA
# 8          HORTALIZAS                ACELGA  ACELGA
# 9          HORTALIZAS                ACELGA  ACELGA
# 10         HORTALIZAS                ACELGA  ACELGA
# 11         HORTALIZAS                ACELGA  ACELGA
# 12         HORTALIZAS                ACELGA  ACELGA
# 13         HORTALIZAS                ACELGA  ACELGA
# 14         HORTALIZAS                ACELGA  ACELGA
# 15         HORTALIZAS                ACELGA  ACELGA
# 16         HORTALIZAS                ACELGA  ACELGA
# 17         HORTALIZAS                ACELGA  ACELGA
# 18         HORTALIZAS                ACELGA  ACELGA
# 19         HORTALIZAS                ACELGA  ACELGA
# 20         HORTALIZAS                ACELGA  ACELGA
# 21         HORTALIZAS                ACELGA  ACELGA
# 22         HORTALIZAS                ACELGA  ACELGA
# 23         HORTALIZAS                ACELGA  ACELGA
# 24         HORTALIZAS                ACELGA  ACELGA
# 25         HORTALIZAS                ACELGA  ACELGA
# 26         HORTALIZAS                ACELGA  ACELGA
# 27         HORTALIZAS                ACELGA  ACELGA
# 28         HORTALIZAS                ACELGA  ACELGA
# 29         HORTALIZAS                ACELGA  ACELGA
# 30         HORTALIZAS                ACELGA  ACELGA
# 31         HORTALIZAS                ACELGA  ACELGA
# 32         HORTALIZAS                ACELGA  ACELGA
# 33         HORTALIZAS                ACELGA  ACELGA
# 34         HORTALIZAS                ACELGA  ACELGA
# 35         HORTALIZAS                ACELGA  ACELGA
# 36         HORTALIZAS                ACELGA  ACELGA
# 37         HORTALIZAS                ACELGA  ACELGA
# 38         HORTALIZAS                ACELGA  ACELGA
# 39         HORTALIZAS                ACELGA  ACELGA
# 40         HORTALIZAS                ACELGA  ACELGA
# 41         HORTALIZAS                ACELGA  ACELGA
# 42         HORTALIZAS                ACELGA  ACELGA
# 43         HORTALIZAS                ACELGA  ACELGA
# 44         HORTALIZAS                ACELGA  ACELGA
# 45         HORTALIZAS                ACELGA  ACELGA
# 46         HORTALIZAS                ACELGA  ACELGA
# 47         HORTALIZAS                ACELGA  ACELGA
# 48         HORTALIZAS                ACELGA  ACELGA
# 49         HORTALIZAS                ACELGA  ACELGA
#
#    DESAGREGACIÓN REGIONAL Y/O SISTEMA PRODUCTIVO   AÑO PERIODO  \
# 0                                         ACELGA  2006   2006B
# 1                                         ACELGA  2006   2006B
# 2                                         ACELGA  2006   2006B
# 3                                         ACELGA  2006   2006B
# 4                                         ACELGA  2006   2006B
# 5                                         ACELGA  2006   2006B
# 6                                         ACELGA  2007   2007A
# 7                                         ACELGA  2007   2007A
# 8                                         ACELGA  2007   2007A
# 9                                         ACELGA  2007   2007A
# 10                                        ACELGA  2007   2007B
# 11                                        ACELGA  2007   2007B
# 12                                        ACELGA  2007   2007B
# 13                                        ACELGA  2007   2007B
# 14                                        ACELGA  2007   2007B
# 15                                        ACELGA  2007   2007B
# 16                                        ACELGA  2008   2008A
# 17                                        ACELGA  2008   2008A
# 18                                        ACELGA  2008   2008A
# 19                                        ACELGA  2008   2008A
# 20                                        ACELGA  2008   2008A
# 21                                        ACELGA  2008   2008B
# 22                                        ACELGA  2008   2008B
# 23                                        ACELGA  2008   2008B
# 24                                        ACELGA  2008   2008B
# 25                                        ACELGA  2008   2008B
# 26                                        ACELGA  2009   2009A
# 27                                        ACELGA  2009   2009A
# 28                                        ACELGA  2009   2009A
# 29                                        ACELGA  2009   2009A
# 30                                        ACELGA  2009   2009A
# 31                                        ACELGA  2009   2009A
# 32                                        ACELGA  2009   2009A
# 33                                        ACELGA  2009   2009B
# 34                                        ACELGA  2009   2009B
# 35                                        ACELGA  2009   2009B
# 36                                        ACELGA  2009   2009B
# 37                                        ACELGA  2009   2009B
# 38                                        ACELGA  2009   2009B
# 39                                        ACELGA  2010   2010A
# 40                                        ACELGA  2010   2010A
# 41                                        ACELGA  2010   2010A
# 42                                        ACELGA  2010   2010A
# 43                                        ACELGA  2010   2010A
# 44                                        ACELGA  2010   2010A
# 45                                        ACELGA  2010   2010A
# 46                                        ACELGA  2010   2010A
# 47                                        ACELGA  2010   2010B
# 48                                        ACELGA  2010   2010B
# 49                                        ACELGA  2010   2010B
#
#     Área Sembrada\n(ha)  Área Cosechada\n(ha)  Producción\n(t)  \
# 0                     2                     1                1
# 1                    82                    80             1440
# 2                     2                     2               26
# 3                     3                     3               48
# 4                     1                     1                5
# 5                     1                     1                6
# 6                    72                    70             1260
# 7                     2                     2               34
# 8                     1                     1                5
# 9                     1                     1                6
# 10                    1                     1                1
# 11                    2                     2               10
# 12                   62                    60             1080
# 13                    1                     1               11
# 14                    3                     3               48
# 15                    1                     1                5
# 16                    2                     1                5
# 17                   62                    60             1080
# 18                    2                     1               10
# 19                    3                     3               48
# 20                    1                     1                5
# 21                    2                     1                5
# 22                   65                    61             1098
# 23                    1                     1               19
# 24                    3                     3               48
# 25                    1                     1                5
# 26                    1                     1                0
# 27                    6                     6              106
# 28                    1                     1                9
# 29                    0                     0                0
# 30                    2                     2               32
# 31                    1                     1                5
# 32                    8                     8               16
# 33                    1                     1                0
# 34                    6                     6              205
# 35                    2                     2               18
# 36                    0                     0                0
# 37                    2                     2               32
# 38                    1                     1                5
# 39                    1                     1                4
# 40                    1                     1                1
# 41                    5                     5              125
# 42                    1                     1                0
# 43                    3                     3               40
# 44                    1                     1                5
# 45                    1                     1                3
# 46                   13                    13               26
# 47                    0                     0                0
# 48                    1                     1                4
# 49                    5                     5              120
#
#     Rendimiento\n(t/ha) ESTADO FISICO PRODUCCION NOMBRE \nCIENTIFICO  \
# 0                  1.00             FRUTO FRESCO       BETA VULGARIS
# 1                 18.00             FRUTO FRESCO       BETA VULGARIS
# 2                 17.33             FRUTO FRESCO       BETA VULGARIS
# 3                 16.00             FRUTO FRESCO       BETA VULGARIS
# 4                 10.00             FRUTO FRESCO       BETA VULGARIS
# 5                  6.00             FRUTO FRESCO       BETA VULGARIS
# 6                 18.00             FRUTO FRESCO       BETA VULGARIS
# 7                 17.00             FRUTO FRESCO       BETA VULGARIS
# 8                 10.00             FRUTO FRESCO       BETA VULGARIS
# 9                  6.00             FRUTO FRESCO       BETA VULGARIS
# 10                 1.00             FRUTO FRESCO       BETA VULGARIS
# 11                 5.00             FRUTO FRESCO       BETA VULGARIS
# 12                18.00             FRUTO FRESCO       BETA VULGARIS
# 13                 8.00             FRUTO FRESCO       BETA VULGARIS
# 14                16.00             FRUTO FRESCO       BETA VULGARIS
# 15                10.00             FRUTO FRESCO       BETA VULGARIS
# 16                 4.50             FRUTO FRESCO       BETA VULGARIS
# 17                18.00             FRUTO FRESCO       BETA VULGARIS
# 18                 8.33             FRUTO FRESCO       BETA VULGARIS
# 19                16.00             FRUTO FRESCO       BETA VULGARIS
# 20                10.00             FRUTO FRESCO       BETA VULGARIS
# 21                 4.80             FRUTO FRESCO       BETA VULGARIS
# 22                18.00             FRUTO FRESCO       BETA VULGARIS
# 23                16.67             FRUTO FRESCO       BETA VULGARIS
# 24                16.00             FRUTO FRESCO       BETA VULGARIS
# 25                10.00             FRUTO FRESCO       BETA VULGARIS
# 26                 0.50             FRUTO FRESCO       BETA VULGARIS
# 27                18.63             FRUTO FRESCO       BETA VULGARIS
# 28                 9.00             FRUTO FRESCO       BETA VULGARIS
# 29                 0.32             FRUTO FRESCO       BETA VULGARIS
# 30                16.00             FRUTO FRESCO       BETA VULGARIS
# 31                10.00             FRUTO FRESCO       BETA VULGARIS
# 32                 2.00             FRUTO FRESCO       BETA VULGARIS
# 33                 0.50             FRUTO FRESCO       BETA VULGARIS
# 34                36.00             FRUTO FRESCO       BETA VULGARIS
# 35                 9.00             FRUTO FRESCO       BETA VULGARIS
# 36                 0.32             FRUTO FRESCO       BETA VULGARIS
# 37                16.00             FRUTO FRESCO       BETA VULGARIS
# 38                10.00             FRUTO FRESCO       BETA VULGARIS
# 39                 5.00             FRUTO FRESCO       BETA VULGARIS
# 40                 1.00             FRUTO FRESCO       BETA VULGARIS
# 41                25.00             FRUTO FRESCO       BETA VULGARIS
# 42                 0.25             FRUTO FRESCO       BETA VULGARIS
# 43                16.00             FRUTO FRESCO       BETA VULGARIS
# 44                10.00             FRUTO FRESCO       BETA VULGARIS
# 45                 2.70             FRUTO FRESCO       BETA VULGARIS
# 46                 2.00             FRUTO FRESCO       BETA VULGARIS
# 47                 0.28             FRUTO FRESCO       BETA VULGARIS
# 48                 5.00             FRUTO FRESCO       BETA VULGARIS
# 49                24.00             FRUTO FRESCO       BETA VULGARIS
#
#    CICLO DE CULTIVO
# 0       TRANSITORIO
# 1       TRANSITORIO
# 2       TRANSITORIO
# 3       TRANSITORIO
# 4       TRANSITORIO
# 5       TRANSITORIO
# 6       TRANSITORIO
# 7       TRANSITORIO
# 8       TRANSITORIO
# 9       TRANSITORIO
# 10      TRANSITORIO
# 11      TRANSITORIO
# 12      TRANSITORIO
# 13      TRANSITORIO
# 14      TRANSITORIO
# 15      TRANSITORIO
# 16      TRANSITORIO
# 17      TRANSITORIO
# 18      TRANSITORIO
# 19      TRANSITORIO
# 20      TRANSITORIO
# 21      TRANSITORIO
# 22      TRANSITORIO
# 23      TRANSITORIO
# 24      TRANSITORIO
# 25      TRANSITORIO
# 26      TRANSITORIO
# 27      TRANSITORIO
# 28      TRANSITORIO
# 29      TRANSITORIO
# 30      TRANSITORIO
# 31      TRANSITORIO
# 32      TRANSITORIO
# 33      TRANSITORIO
# 34      TRANSITORIO
# 35      TRANSITORIO
# 36      TRANSITORIO
# 37      TRANSITORIO
# 38      TRANSITORIO
# 39      TRANSITORIO
# 40      TRANSITORIO
# 41      TRANSITORIO
# 42      TRANSITORIO
# 43      TRANSITORIO
# 44      TRANSITORIO
# 45      TRANSITORIO
# 46      TRANSITORIO
# 47      TRANSITORIO
# 48      TRANSITORIO
# 49      TRANSITORIO

# %%
# Transformacion del periodo de cosechas

cosecha_periodo = Cosechas_1['PERIODO'].str.replace('A',"-1")
cosecha_periodo = cosecha_periodo.str.replace('B',"-2")
cosecha_periodo = cosecha_periodo.str.split('-')
cosecha_periodo = cosecha_periodo.tolist()
cosecha_periodo = pd.DataFrame(cosecha_periodo, columns=['anio','periodo'])
cosecha_periodo
# Out:
#         anio periodo
# 0       2006       2
# 1       2006       2
# 2       2006       2
# 3       2006       2
# 4       2006       2
# ...      ...     ...
# 206063  2017       2
# 206064  2017       2
# 206065  2018       1
# 206066  2018       1
# 206067  2018       1
#
# [206068 rows x 2 columns]

# %%
#Que podemos concluir sobre esto 

Max_area_sembrada=Cosechas_1['Área Sembrada\n(ha)'].sum()
Max_area_cosechada=Cosechas_1['Área Cosechada\n(ha)'].sum()
Max_produccion=Cosechas_1['Producción\n(t)'].sum()
Max_rendimiento=Cosechas_1['Rendimiento\n(t/ha)'].mean()

print(Max_area_sembrada)
print(Max_area_cosechada)
print(Max_produccion)
print(Max_rendimiento)
# Out:
# 59981001
# 51397382
# 575079242
# 9.238819651096758

# %%
#Correlación frente a los campos presentados en el dataSet 

#Correlación numero 1
Correlacion_1=Cosechas_1['Área Sembrada\n(ha)'].corr(Cosechas_1['Área Cosechada\n(ha)'])

print("La correlacion entre Área Sembrada y Área Cosechada es igual a:" + str(Correlacion_1))

#Correlacion
Correlacion_2=Cosechas_1['Área Sembrada\n(ha)'].corr(Cosechas_1['Producción\n(t)'])

print("La correlacion entre Área Sembrada y Producción es igual a:" + str(Correlacion_2))

#Correlacion 
Correlacion_3=Cosechas_1['Área Sembrada\n(ha)'].corr(Cosechas_1['Rendimiento\n(t/ha)'])

print("La correlacion entre Área Sembrada y Rendimiento es igual a:" + str(Correlacion_3))
# Out:
# La correlacion entre Área Sembrada y Área Cosechada es igual a:0.9769065633037763
# La correlacion entre Área Sembrada y Producción es igual a:0.44449901565623645
# La correlacion entre Área Sembrada y Rendimiento es igual a:0.03563810095326786

# %%
#Correlacion área cosechada
Correlacion_2_b=Cosechas_1['Área Cosechada\n(ha)'].corr(Cosechas_1['Producción\n(t)'])

print("La correlacion entre Área Cosechada(ha) y Producción(t) es igual a:" + str(Correlacion_2_b))

#Correlacion
Correlacion_3_b=Cosechas_1['Área Cosechada\n(ha)'].corr(Cosechas_1['Rendimiento\n(t/ha)'])

print("La correlacion entre Área Cosechada y Rendimiento es igual a:" + str(Correlacion_3_b))
# Out:
# La correlacion entre Área Cosechada(ha) y Producción(t) es igual a:0.4448940442330128
# La correlacion entre Área Cosechada y Rendimiento es igual a:0.03363618650321916

# %%
#Correlacion Porduccion
Correlacion_2_c=Cosechas_1['Producción\n(t)'].corr(Cosechas_1['Rendimiento\n(t/ha)'])

print("La correlacion entre Producción y Rendimiento es igual a:" + str(Correlacion_2_c))
# Out:
# La correlacion entre Producción y Rendimiento es igual a:0.2479737371164496

# %%
#Concluimos que las variables tienen una relacion directo cuando estan por encima de 0,5
#Cuando las variables estan entre 0,3 y 0,49 son de relacion moderada
#Cuando las variables estan entre 0,1 y 0,29 son de relacion debil
#Cuando las variables estan entre 0 y 0,09 son de relacion inexistente   

#Por lo que definimos que las variables como Área Sembrada y Área Cosechada tienen una relacion directa
#Por lo que definimos que las variables como Área Sembrada y Producción tienen una relacion moderada
#Por lo que definimos que las variables como Área Sembrada y Rendimiento tienen una relacion inexistente

#Por lo que definimos que las variables como Área Cosechada y Producción tienen una relacion moderada
#Por lo que definimos que las variables como Área Cosechada y Rendimiento tienen una relacion inexistente

#Por lo que definimos que las variables como Producción y Rendimiento tienen una relacion debil

# %%
#tabla de frecuencias 

#Se realiza tanto para el cultivo, como para el departamento esto con tal de determinar
#en que zonas y que cultivos tienen mayor cantidad de datos para ser estudiados

#Se define una funcion que nos permita realizar este cálculo para cualquier tipo de campo 
#que se quiera analizar respecto a su frecuencia relativa

def  rel_freq (x): 
    freqs = [(value, x.count (value) / len (x)) for value in set (x)] 
    return freqs

# %%
def  rel_freq (x): 
    freqs = [(value, x.count (value) / len (x)) for value in set (x)] 
    return freqs

# %%
freq=rel_freq(list(Cosechas_1['DEPARTAMENTO']))
freq_tabla=pd.DataFrame(freq)
freq_tabla=freq_tabla.set_axis(['Departamento','Frecuencia relativa'],axis=1)
freq_tabla['Frecuencia relativa %']=freq_tabla['Frecuencia relativa'].apply(lambda x:format(x,'.2%'))
Mayor_frecuencia_departamentos = freq_tabla.sort_values('Frecuencia relativa',ascending=False)

# %%
#Detallamos de mayor a menor los departamentos donde mas se conecentra la recolecta de informacion 
Mayor_frecuencia_departamentos
# Out:
#                 Departamento  Frecuencia relativa Frecuencia relativa %
# 1                     BOYACA             0.099851                 9.99%
# 26                 ANTIOQUIA             0.091033                 9.10%
# 10              CUNDINAMARCA             0.086404                 8.64%
# 17                     HUILA             0.077285                 7.73%
# 27           VALLE DEL CAUCA             0.076548                 7.65%
# 16                 SANTANDER             0.071200                 7.12%
# 25                    NARIÑO             0.065245                 6.52%
# 21        NORTE DE SANTANDER             0.047319                 4.73%
# 19                    TOLIMA             0.041710                 4.17%
# 8                      CAUCA             0.040690                 4.07%
# 5                     CALDAS             0.025923                 2.59%
# 18                      META             0.025433                 2.54%
# 20                   CORDOBA             0.024851                 2.49%
# 24                   BOLIVAR             0.024594                 2.46%
# 0                      CESAR             0.023715                 2.37%
# 15                     SUCRE             0.021852                 2.19%
# 2                      CHOCO             0.019780                 1.98%
# 4                    QUINDIO             0.018989                 1.90%
# 29                 MAGDALENA             0.018965                 1.90%
# 6                  ATLANTICO             0.018484                 1.85%
# 11                LA GUAJIRA             0.015946                 1.59%
# 23                  CASANARE             0.015247                 1.52%
# 9                  RISARALDA             0.013636                 1.36%
# 14                   CAQUETA             0.011375                 1.14%
# 30                  PUTUMAYO             0.008619                 0.86%
# 28                    ARAUCA             0.004159                 0.42%
# 7                    VICHADA             0.003242                 0.32%
# 12                  AMAZONAS             0.002752                 0.28%
# 31                  GUAVIARE             0.002363                 0.24%
# 13                    VAUPES             0.001335                 0.13%
# 22                   GUAINIA             0.000786                 0.08%
# 3   SAN ANDRES Y PROVIDENCIA             0.000670                 0.07%

# %%
freq=rel_freq(list(Cosechas_1['CULTIVO']))
freq_tabla=pd.DataFrame(freq)
freq_tabla=freq_tabla.set_axis(['CULTIVO','Frecuencia relativa'],axis=1)
freq_tabla['Frecuencia relativa %']=freq_tabla['Frecuencia relativa'].apply(lambda x:format(x,'.5%'))
Mayor_frecuencia_cultivo = freq_tabla.sort_values('Frecuencia relativa',ascending=False)

# %%
#Detallamos de mayor a menor los departamentos donde mas se conecentra la recolecta de informacion
Mayor_frecuencia_cultivo.tail(50)
# Out:
#                  CULTIVO  Frecuencia relativa Frecuencia relativa %
# 34             CHAMPIÑON             0.000053              0.00534%
# 37                    TE             0.000053              0.00534%
# 214               COCONA             0.000049              0.00485%
# 128             RAMBUTAN             0.000049              0.00485%
# 35               OREGANO             0.000049              0.00485%
# 31            MANZANILLA             0.000049              0.00485%
# 44             FRAMBUESA             0.000044              0.00437%
# 25   PLANTAS MEDICINALES             0.000044              0.00437%
# 152             AMARANTO             0.000044              0.00437%
# 71                  CHIA             0.000039              0.00388%
# 204               MIMBRE             0.000039              0.00388%
# 90          PALMA AMARGA             0.000034              0.00340%
# 146          CHACHAFRUTO             0.000034              0.00340%
# 147              CENTENO             0.000034              0.00340%
# 49        PALMA ROBELINA             0.000034              0.00340%
# 154              TORONJA             0.000029              0.00291%
# 127           FITOSPORUM             0.000029              0.00291%
# 145               COROZO             0.000029              0.00291%
# 208            ACHICORIA             0.000029              0.00291%
# 118              CHONQUE             0.000029              0.00291%
# 138                 NONI             0.000024              0.00243%
# 32                  RUBA             0.000024              0.00243%
# 105                MAMEY             0.000024              0.00243%
# 186             ORELLANA             0.000024              0.00243%
# 165             VAINILLA             0.000024              0.00243%
# 215      CORDELINE CINTA             0.000019              0.00194%
# 192            TREE FERN             0.000015              0.00146%
# 168               ENELDO             0.000015              0.00146%
# 23                 UMARI             0.000015              0.00146%
# 83                 CAIMO             0.000015              0.00146%
# 160             ORQUIDEA             0.000015              0.00146%
# 94               LENTEJA             0.000015              0.00146%
# 69             ALGARROBO             0.000015              0.00146%
# 203             LIMONIUM             0.000010              0.00097%
# 116            POMARROSA             0.000010              0.00097%
# 55        FLOR DE SAFARI             0.000010              0.00097%
# 216          HIERBABUENA             0.000010              0.00097%
# 91                PROTEA             0.000010              0.00097%
# 114              STATICE             0.000010              0.00097%
# 54                  ANIS             0.000010              0.00097%
# 169             COCCULUS             0.000010              0.00097%
# 134            ALCACHOFA             0.000005              0.00049%
# 57                LAUREL             0.000005              0.00049%
# 59                BACURI             0.000005              0.00049%
# 185            CANYARANA             0.000005              0.00049%
# 88                  BORE             0.000005              0.00049%
# 104              MORINGA             0.000005              0.00049%
# 151            TANGARANA             0.000005              0.00049%
# 143              ESPARTO             0.000005              0.00049%
# 222            CALENDULA             0.000005              0.00049%

# %%
#Desviacion estandar de rendimiento
dsv_rendimiento=Cosechas_1['Rendimiento\n(t/ha)'].std()
dsv_rendimiento
# Out:
# 14.888659058905967

# %%
#Promedio de rendimiento
mean_rendimiento =Cosechas_1['Rendimiento\n(t/ha)'].mean()
mean_rendimiento
# Out:
# 9.238819651096758

# %%
#Con las medias tomadas anteriormente podemos graficar algunas para poder tener 
#una vizualisaciones que nos permitan entender mejor los datos

# %%
#La siguiente gráfica muestra el top 5 de zonas donde mas datos se obtienen 
sns.catplot(x="Departamento", y="Frecuencia relativa" , data=Mayor_frecuencia_departamentos.head(5), kind = "bar",height = 6, aspect = 3,palette=sns.color_palette(['blue']));

# %%
#La siguiente gráfica muestra el top 5 de alimentos que mas se cultivan y donde mas se obtuvieron datos
#El maiz toma una ventaja significativa frente a los demas
sns.catplot(x="CULTIVO", y="Frecuencia relativa" , data=Mayor_frecuencia_cultivo.head(5), kind = "bar",height = 6, aspect = 3,palette=sns.color_palette(['green']));

# %%
Maiz=Cosechas_1[(Cosechas_1['CULTIVO']=='MAIZ')]

# %%
Maiz['Rendimiento\n(t/ha)'].mean()
# Out:
# 1.959690974033841

# %% [markdown]
# Maiz

# %%
Maiz['Área Sembrada\n(ha)'].sum()
# Out:
# 7411203

# %%
Maiz['Área Cosechada\n(ha)'].sum()
# Out:
# 6700897

# %%
#Apartir de los codigos de arriba denotamos que el maiz pierde en gran cantidad el area sembrada
# en casi 700.000
